#    -------------------------------------- - 34.2/35.6 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 34.6/35.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  35.1/35.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  35.5/35.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  35.6/35.6 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 35.6/35.6 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: cmake
# Successfully installed cmake-3.30.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dlib
# Out:
# Collecting dlib
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: dlib
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [75 lines of output]
#   C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py:234: SyntaxWarning: invalid escape sequence '\('
#     major = re.findall("set\(CPACK_PACKAGE_VERSION_MAJOR.*\"(.*)\"", open(cmake_file).read())[0]
#   C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py:235: SyntaxWarning: invalid escape sequence '\('
#     minor = re.findall("set\(CPACK_PACKAGE_VERSION_MINOR.*\"(.*)\"", open(cmake_file).read())[0]
#   C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py:236: SyntaxWarning: invalid escape sequence '\('
#     patch = re.findall("set\(CPACK_PACKAGE_VERSION_PATCH.*\"(.*)\"", open(cmake_file).read())[0]
#   running bdist_wheel
#   running build
#   running build_ext
#   C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py:163: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Building extension for Python 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\build\lib.win-amd64-cpython-312 -DPYTHON_EXECUTABLE=C:\Users\MTBH\anaconda3\python.exe -DDLIB_USE_FFMPEG=OFF -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\build\lib.win-amd64-cpython-312 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:5 (message):
#
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#     You must use Visual Studio to build a python extension on windows.  If you
#     are getting this error it means you have not installed Visual C++.  Note
#     that there are many flavors of Visual Studio, like Visual Studio for C#
#     development.  You need to install Visual Studio for C++.
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#   -- Configuring incomplete, errors occurred!
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py", line 243, in <module>
#       setup(
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\__init__.py", line 104, in setup
#       return distutils.core.setup(**attrs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\core.py", line 184, in setup
#       return run_commands(dist)
#              ^^^^^^^^^^^^^^^^^^
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\core.py", line 200, in run_commands
#       dist.run_commands()
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\dist.py", line 967, in run_command
#       super().run_command(command)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\wheel\bdist_wheel.py", line 368, in run
#       self.run_command("build")
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py", line 316, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\dist.py", line 967, in run_command
#       super().run_command(command)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\command\build.py", line 132, in run
#       self.run_command(cmd_name)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\cmd.py", line 316, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\dist.py", line 967, in run_command
#       super().run_command(command)
#     File "C:\Users\MTBH\anaconda3\Lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py", line 168, in run
#       self.build_extension(ext)
#     File "C:\Users\MTBH\AppData\Local\Temp\pip-install-29aaynci\dlib_301f13e3a7034c659594457a4f7b95e6\setup.py", line 206, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\MTBH\anaconda3\Lib\subprocess.py", line 413, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\MTBH\\AppData\\Local\\Temp\\pip-install-29aaynci\\dlib_301f13e3a7034c659594457a4f7b95e6\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\MTBH\\AppData\\Local\\Temp\\pip-install-29aaynci\\dlib_301f13e3a7034c659594457a4f7b95e6\\build\\lib.win-amd64-cpython-312', '-DPYTHON_EXECUTABLE=C:\\Users\\MTBH\\anaconda3\\python.exe', '-DDLIB_USE_FFMPEG=OFF', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\MTBH\\AppData\\Local\\Temp\\pip-install-29aaynci\\dlib_301f13e3a7034c659594457a4f7b95e6\\build\\lib.win-amd64-cpython-312', '-A', 'x64']' returned non-zero exit status 1.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for dlib
# ERROR: Could not build wheels for dlib, which is required to install pyproject.toml-based projects

# %%
import cv2
import numpy as np
import dlib
import os
from imutils import face_utils
from google.colab import drive
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[41], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 import dlib
#       4 import os
#       5 from imutils import face_utils
#
# ModuleNotFoundError: No module named 'dlib'

# %%
drive.mount('/content/drive')

# %%
path = '/content/drive/MyDrive/test_opencv'

# %%
img = cv2.imread('D:/ThiGiacMayTinh/ThiGiacMayTinh500.jpg')

# Hiển thị ảnh gốc
cv2.imshow('1.jpg', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
net = cv2.dnn.readNetFromCaffe(
    './test_opencv/deploy.prototxt.txt',
    './test_opencv/res10_300x300_ssd_iter_140000_fp16.caffemodel'
)

# Chuẩn bị dữ liệu đầu vào
# img: Đây là ảnh đầu vào mà bạn muốn nhận dạng khuôn mặt. Trong trường hợp của bạn, bạn đã đọc ảnh từ tệp "face.png".
# 1.0: Đây là tỷ lệ co giãn cho ảnh. Trong trường hợp này, ảnh sẽ không bị co giãn hoặc mở rộng, và giữ nguyên kích thước ban đầu.
# (300, 300): Đây là kích thước mà mô hình yêu cầu cho ảnh đầu vào. Mô hình mà bạn đang sử dụng mong muốn ảnh có kích thước 300x300 pixel. Do đó, bạn co giãn hoặc cắt ảnh đầu vào thành kích thước này.
# (104, 177, 123): Đây là giá trị trung bình màu sắc được trừ đi từ mỗi pixel của ảnh. Điều này thường được sử dụng để chuẩn hóa dữ liệu đầu vào. Trong trường hợp này, các giá trị này thường được lấy từ dữ liệu huấn luyện của mô hình.
# swapRB=False: Đây là một cờ để xác định xem có cần hoán đổi các kênh màu đỏ và xanh (Red-Blue) trong ảnh hay không. Trong trường hợp này, bạn đã đặt nó thành False, tức là không hoán đổi kênh mà
blob = cv2.dnn.blobFromImage(img, 1.0, (300, 300), (104, 177, 123), swapRB=False)

# Đặt dữ liệu đầu vào cho mạng
net.setInput(blob)

# Chạy mạng để phát hiện khuôn mặt
faces = net.forward()

# Lấy kích thước của ảnh đầu vào
h = img.shape[0]
w = img.shape[1]

# In thông tin
print(faces.shape)
print(faces[0, 0, 0, ])

# Duyệt từng khuôn mặt đã được phát hiện
for i in range(0, faces.shape[2]):
    confidence = faces[0,0,i,2]
    # Kiểm tra nếu mặt có độ tin cậy là 0.5
    if confidence>0.5:
        # Trích xuất tọa độ
        print(faces[0, 0, i, 3:7])
        startx = int(faces[0, 0, i, 3]*w)
        starty = int(faces[0, 0, i, 4]*h)
        endx = int(faces[0, 0, i, 5]*w)
        endy = int(faces[0, 0, i, 6]*h)
        print(startx, starty, endx, endy)
        
        # Vẽ hình chữ nhật xung quanh khuôn mặt đã phát hiện
        cv2.rectangle(img, (startx, starty), (endx, endy), (0, 255, 0),)
        
        # Hiển thị độ tin cậy
        text = 'Face: {:.2f}%'.format(confidence*100);
        cv2.putText(img, text, (startx, starty-10), cv2.FONT_HERSHEY_PLAIN, 1, (255,255,255),)

# Hiển thị ảnh gốc
cv2.imshow('Kết quả', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 net = cv2.dnn.readNetFromCaffe(
#       2     './models/deploy.prototxt.txt',
#       3     './models/res10_300x300_ssd_iter_140000_fp16.caffemodel'
#       4 )
#       6 # Chuẩn bị dữ liệu đầu vào
#       7 # img: Đây là ảnh đầu vào mà bạn muốn nhận dạng khuôn mặt. Trong trường hợp của bạn, bạn đã đọc ảnh từ tệp "face.png".
#       8 # 1.0: Đây là tỷ lệ co giãn cho ảnh. Trong trường hợp này, ảnh sẽ không bị co giãn hoặc mở rộng, và giữ nguyên kích thước ban đầu.
#       9 # (300, 300): Đây là kích thước mà mô hình yêu cầu cho ảnh đầu vào. Mô hình mà bạn đang sử dụng mong muốn ảnh có kích thước 300x300 pixel. Do đó, bạn co giãn hoặc cắt ảnh đầu vào thành kích thước này.
#      10 # (104, 177, 123): Đây là giá trị trung bình màu sắc được trừ đi từ mỗi pixel của ảnh. Điều này thường được sử dụng để chuẩn hóa dữ liệu đầu vào. Trong trường hợp này, các giá trị này thường được lấy từ dữ liệu huấn luyện của mô hình.
#      11 # swapRB=False: Đây là một cờ để xác định xem có cần hoán đổi các kênh màu đỏ và xanh (Red-Blue) trong ảnh hay không. Trong trường hợp này, bạn đã đặt nó thành False, tức là không hoán đổi kênh mà
#      12 blob = cv2.dnn.blobFromImage(img, 1.0, (300, 300), (104, 177, 123), swapRB=False)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1126: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "./models/deploy.prototxt.txt" in function 'cv::dnn::ReadProtoFromTextFile'

# %%
# Tải mô hình đã được huấn luyện từ trước
net = cv2.dnn.readNetFromCaffe('/content/drive/MyDrive/test_opencv/deploy.prototxt.txt', '/content/drive/MyDrive/test_opencv/res10_300x300_ssd_iter_140000_fp16.caffemodel')
 
# Chuẩn bị dữ liệu đầu vào
# img: Đây là ảnh đầu vào mà bạn muốn nhận dạng khuôn mặt. Trong trường hợp của bạn, bạn đã đọc ảnh từ tệp "face.png".
# 1.0: Đây là tỷ lệ co giãn cho ảnh. Trong trường hợp này, ảnh sẽ không bị co giãn hoặc mở rộng, và giữ nguyên kích thước ban đầu.
# (300, 300): Đây là kích thước mà mô hình yêu cầu cho ảnh đầu vào. Mô hình mà bạn đang sử dụng mong muốn ảnh có kích thước 300x300 pixel. Do đó, bạn co giãn hoặc cắt ảnh đầu vào thành kích thước này.
# (104, 177, 123): Đây là giá trị trung bình màu sắc được trừ đi từ mỗi pixel của ảnh. Điều này thường được sử dụng để chuẩn hóa dữ liệu đầu vào. Trong trường hợp này, các giá trị này thường được lấy từ dữ liệu huấn luyện của mô hình.
# swapRB=False: Đây là một cờ để xác định xem có cần hoán đổi các kênh màu đỏ và xanh (Red-Blue) trong ảnh hay không. Trong trường hợp này, bạn đã đặt nó thành False, tức là không hoán đổi kênh mà
blob = cv2.dnn.blobFromImage(img, 1.0, (300, 300), (104, 177, 123), swapRB=False)
 
# Đặt dữ liệu đầu vào cho mạng
net.setInput(blob)
 
# Chạy mạng để phát hiện khuôn mặt
faces = net.forward()
 
# Lấy kích thước của ảnh đầu vào
h = img.shape[0]
w = img.shape[1]
 
# In thông tin
print(faces.shape)
print(faces[0, 0, 0, ])
 
# Duyệt từng khuôn mặt đã được phát hiện
for i in range(0, faces.shape[2]):
    confidence = faces[0,0,i,2]
    # Kiểm tra nếu mặt có độ tin cậy là 0.5
    if confidence>0.5:
        # Trích xuất tọa độ
        print(faces[0, 0, i, 3:7])
        startx = int(faces[0, 0, i, 3]*w)
        starty = int(faces[0, 0, i, 4]*h)
        endx = int(faces[0, 0, i, 5]*w)
        endy = int(faces[0, 0, i, 6]*h)
        print(startx, starty, endx, endy)
 
        # Vẽ hình chữ nhật xung quanh khuôn mặt đã phát hiện
        cv2.rectangle(img, (startx, starty), (endx, endy), (0, 255, 0),)
 
        # Hiển thị độ tin cậy
        text = 'Face: {:.2f}%'.format(confidence*100);
        cv2.putText(img, text, (startx, starty-10), cv2.FONT_HERSHEY_PLAIN, 1, (255,255,255),)
 
# Hiển thị ảnh gốc
cv2_imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Tải mô hình đã được huấn luyện từ trước
# ----> 2 net = cv2.dnn.readNetFromCaffe('/content/drive/MyDrive/test_opencv/deploy.prototxt.txt', '/content/drive/MyDrive/test_opencv/res10_300x300_ssd_iter_140000_fp16.caffemodel')
#       4 # Chuẩn bị dữ liệu đầu vào
#       5 # img: Đây là ảnh đầu vào mà bạn muốn nhận dạng khuôn mặt. Trong trường hợp của bạn, bạn đã đọc ảnh từ tệp "face.png".
#       6 # 1.0: Đây là tỷ lệ co giãn cho ảnh. Trong trường hợp này, ảnh sẽ không bị co giãn hoặc mở rộng, và giữ nguyên kích thước ban đầu.
#       7 # (300, 300): Đây là kích thước mà mô hình yêu cầu cho ảnh đầu vào. Mô hình mà bạn đang sử dụng mong muốn ảnh có kích thước 300x300 pixel. Do đó, bạn co giãn hoặc cắt ảnh đầu vào thành kích thước này.
#       8 # (104, 177, 123): Đây là giá trị trung bình màu sắc được trừ đi từ mỗi pixel của ảnh. Điều này thường được sử dụng để chuẩn hóa dữ liệu đầu vào. Trong trường hợp này, các giá trị này thường được lấy từ dữ liệu huấn luyện của mô hình.
#       9 # swapRB=False: Đây là một cờ để xác định xem có cần hoán đổi các kênh màu đỏ và xanh (Red-Blue) trong ảnh hay không. Trong trường hợp này, bạn đã đặt nó thành False, tức là không hoán đổi kênh mà
#      10 blob = cv2.dnn.blobFromImage(img, 1.0, (300, 300), (104, 177, 123), swapRB=False)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1126: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "/content/drive/MyDrive/test_opencv/deploy.prototxt.txt" in function 'cv::dnn::ReadProtoFromTextFile'
