# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\mtbh\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mtbh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 10, 10, 10, 10]

x1 = [1, 2, 3, 4, 5]
y1 = [20, 15, 8, 9, 20]

x2 = [1, 2, 3, 4, 5]
y2 = [24, 12, 2, 2, 24]

plt.plot(x, y, 'bo-', label='Dữ liệu') # Vẽ đường 1
plt.plot(x1, y1, marker='o', color='r', linestyle='-', label='Dữ liệu-1')# Vẽ đường 2
plt.plot(x2, y2, marker='o', color='r', linestyle='-', label='Dữ liệu-2')# Vẽ đường 3
plt.legend() # Hiển thị chú giải
plt.xlabel('Trục x') # Đặt nhãn cho trục x
plt.ylabel('Trục y') # Đặt nhãn cho trục y
plt.show()

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values = [15, 10, 25, 12, 18]

plt.bar(categories, values, color='g', alpha=0.6) # Vẽ biểu đồ cột
plt.xlabel('Danh mục') # Đặt nhãn cho trục x
plt.ylabel('Giá trị') # Đặt nhãn cho trục y
plt.show() # Hiển thị biểu đồ

# %%
my_labels = ['A', 'B', 'C', 'D']
sizes = [30, 20, 25, 25]
my_colors = ['red', 'green', 'blue', 'yellow']

plt.pie(sizes, labels=my_labels, colors = my_colors, autopct='%1.1f%%') # Vẽ biểu đồ hình tròn
plt.title('Biểu đồ hình tròn')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 19, 22, 35, 25]

plt.scatter(x, y, c='r', marker='o', label='Dữ liệu')  # Vẽ biểu đồ phân tán
plt.title('Biểu đồ phân tán ví dụ')  # Đặt tiêu đề cho biểu đồ
plt.xlabel('Trục x')  # Đặt nhãn cho trục x
plt.ylabel('Trục y')  # Đặt nhãn cho trục y
plt.legend()  # Hiển thị chú giải
plt.show()  # Hiển thị biểu đồ

# %%
import matplotlib.pyplot as plt

data = [15, 18, 22, 30, 35, 45, 54, 55, 65]


plt.boxplot(data)  # Vẽ biểu đồ hộp
plt.title('Biểu đồ hộp ví dụ')  # Đặt tiêu đề cho biểu đồ
plt.ylabel('Giá trị')  # Đặt nhãn cho trục y
plt.show()  # Hiển thị biểu đồ

# %%
import matplotlib.pyplot as plt

data = [15, 18, 22, 30, 35, 45, 50, 55, 65]

plt.violinplot(data)  # Vẽ biểu đồ violin
plt.title('Biểu đồ violin ví dụ')  # Đặt tiêu đề cho biểu đồ
plt.ylabel('Giá trị')  # Đặt nhãn cho trục y
plt.show()  # Hiển thị biểu đồ

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mtbh\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\mtbh\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\mtbh\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mtbh\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\mtbh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.4 kB ? eta -:--:--
#    - -------------------------------------- 10.2/301.4 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/301.4 kB 217.9 kB/s eta 0:00:02
#    --- ----------------------------------- 30.7/301.4 kB 262.6 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/301.4 kB 435.7 kB/s eta 0:00:01
#    ----------------------- -------------- 184.3/301.4 kB 930.9 kB/s eta 0:00:01
#    ---------------------------------------- 301.4/301.4 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text = "Python is an amazing language for data visualization and word clouds."

wordcloud = WordCloud(width=800, height=400).generate(text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Biểu đồ đám mây từ văn bản ví dụ')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 4, 3, 7, 6]

N = len(categories)
values += values[:1]

angles = [n / float(N) * 2 * np.pi for n in range(N)]
angles += angles[:1]

plt.polar(angles, values, 'o-', linewidth=2)
plt.fill(angles, values, 'b', alpha=0.1)
plt.title('Biểu đồ radar ví dụ')
plt.show()
