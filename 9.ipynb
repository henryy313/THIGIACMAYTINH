# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'D:/ThiGiacMayTinh/1.jpg'
im = Image.open(my_path)
plt.imshow(im)

# %%
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[180 179 170 ... 181 171 163]
#  [175 175 167 ... 177 169 163]
#  [170 171 165 ... 175 169 165]
#  ...
#  [172 176 179 ... 143 142 144]
#  [163 168 173 ... 147 145 143]
#  [153 159 166 ... 150 146 142]]

# %%
plt.figure()
plt.hist(im_array.flatten(), bins=128)
plt.title('Biểu đồ Histogram của ảnh')
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
# Đường dẫn ảnh
my_path = 'D:/ThiGiacMayTinh/1.jpg'

# Đọc ảnh và hiển thị ảnh với trục tọa độ
im = Image.open(my_path).convert("L")

# Hiển thị ảnh trên trục tọa độ
plt.imshow(im)

# Tạo một ình vẽ mới
plt.figure()

# Đặt màu sắc là xám
plt.gray()

# Vẽ biểu đồ đường biên (contour) của ảnh
plt.contour(im, origin="image")

# Đảm bảo tỷ lệ trục x và trục y trên biểu đồ là bằng nhau
plt.axis('equal')

# hiển thị ảnh
plt.show()
